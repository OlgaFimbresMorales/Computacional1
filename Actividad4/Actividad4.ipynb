# %%
file = open('act.txt', 'r')

print file.read()
# Out:
# 1900	24.42
# 1901	20.99
# 1902	21.41
# 1903	22.82
# 1904	15.94
# 1905	16.93
# 1906	26.18
# 1907	19.42
# 1908	22.55
# 1909	25.15
# 1910	21.54
# 1911	21.34
# 1912	20.69
# 1913	27.10
# 1914	21.83
# 1915	24.26
# 1916	23.15
# 1917	21.12
# 1918	15.75
# 1919	27.62
# 1920	17.20
# 1921	26.43
# 1922	22.52
# 1923	20.51
# 1924	24.93
# 1925	23.48
# 1926	22.64
# 1927	22.69
# 1928	24.85
# 1929	24.59
# 1930	24.82
# 1931	24.27
# 1932	30.47
# 1933	29.38
# 1934	18.86
# 1935	21.28
# 1936	18.81
# 1937	28.80
# 1938	24.29
# 1939	24.93
# 1940	21.10
# 1941	23.43
# 1942	23.39
# 1943	21.32
# 1944	23.49
# 1945	19.70
# 1946	22.06
# 1947	24.87
# 1948	19.78
# 1949	28.70
# 1950	27.51
# 1951	25.31
# 1952	26.59
# 1953	28.82
# 1954	27.42
# 1955	23.24
# 1956	22.76
# 1957	25.03
# 1958	23.72
# 1959	19.49
# 1960	25.94
# 1961	20.60
# 1962	22.73
# 1963	19.52
# 1964	21.78
# 1965	22.98
# 1966	24.31
# 1967	24.48
# 1968	20.94
# 1969	22.66
# 1970	19.08
# 1971	21.30
# 1972	24.48
# 1973	24.79
# 1974	24.25
# 1975	27.08
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

with open("act.txt") as f:
    data = f.read()

data = data.split('\n')

x = [row.split(' ')[0] for row in data]
y = [row.split(' ')[1] for row in data]

fig = plt.figure()

ax1 = fig.add_subplot(111)

ax1.set_title("Plot title...")    
ax1.set_xlabel('your x label..')
ax1.set_ylabel('your y label...')

ax1.plot(x,y, c='r', label='the data')

leg = ax1.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-045b465e6b1d> in <module>()
#       8
#       9 x = [row.split(' ')[0] for row in data]
# ---> 10 y = [row.split(' ')[1] for row in data]
#      11
#      12 fig = plt.figure()
#
# IndexError: list index out of range

# %%
import pylab

datalist = [ ( pylab.loadtxt('act.txt'), label ) for filename, label in ('datosA','label 1'),('datosB','label 2') ]

for data, label in datalist:
    pylab.plot( data[:,0], data[:,1], label=label)
 

pylab.legend()
pylab.title("Temperatura")
pylab.xlabel("X Axis Label")
pylab.ylabel("Y Axis Label")

# %%
import matplotlib.pyplot as plt 

plt.plotfile('act.txt', delimiter=' ', cols=(0, 1), 
             names=('col1', 'col2'), marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt 

plt.plotfile('actb.txt', delimiter=' ', cols=(0, 1), 
             names=('col1', 'col2'), marker='o')
plt.show()

# %%
import pylab

datalist = [ ( pylab.loadtxt('actb.txt'), label ) for filename, label in ('datosA','label 1'),('datosB','label 2') ]

for data, label in datalist:
    pylab.plot( data[:,0], data[:,1], label=label)
 

pylab.legend()
pylab.title("Temperatura")
pylab.xlabel("X Axis Label")
pylab.ylabel("Y Axis Label")

# %%
xes = []
ys = []
with open('act.txt') as f:
     for line in f:
         x, y = l.split()
         xes.append(x)
         ys.append(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-79dc6d8e71db> in <module>()
#       3 with open('act.txt') as f:
#       4      for line in f:
# ----> 5          x, y = l.split()
#       6          xes.append(x)
#       7          ys.append(y)
#
# NameError: name 'l' is not defined
